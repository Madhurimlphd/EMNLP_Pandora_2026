# %% [markdown]
# In this notebook, 1] we calculate fleiss kappa among prompt1, prompt2, prompt3, prompt4 and prompt5 for each LLM models <br/>
# [2] we calculate fleiss kappa among LLM models for each prompt <br/>

# %% [markdown]
# **Fleiss kappa among prompt1, prompt2, prompt3, prompt4, prompt5 among each LLM models**

# %% [markdown]
# **GPT 5.4**

# %%
import pandas as pd
df1 = pd.read_csv("LLM_annotation2/GPT_5.4_EXIST2023.csv")
df2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_EXIST2023.csv")
df3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_EXIST2023.csv")
df4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age18.csv")
df5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age23.csv")
df6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age46.csv")

# %%
from statsmodels.stats.inter_rater import aggregate_raters,fleiss_kappa



#df = pd.read_csv("LLM_processed_dataset/All_LLM_EXIST2023.csv")

#llm = pd.concat(
#    [
#        df1["GPT_5.4"],
#        df2["GPT_5.4"],
#        df3["GPT_5.4"],
#        df4["GPT_5.4"],
#        df6["GPT_5.4"],
#        df5["GPT_5.4"],
#    ],
#    axis=1,
#)

df_llm = (
    df1
    .merge(df1[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df2[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df3[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df4[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df5[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df6[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

llm =df_llm[["GPT_5.4_df1","GPT_5.4_df2","GPT_5.4_df3","GPT_5.4_df4","GPT_5.4_df5","GPT_5.4_df6"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT 5.4 models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT 5.4 models
# 0.8973763440703826

# %% [markdown]
# **GPT 5.4 mini**

# %%
df1 = pd.read_csv("LLM_annotation2/GPT_5.4_mini_EXIST2023.csv")
df2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_mini_EXIST2023.csv")
df3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_mini_EXIST2023.csv")
df4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age18.csv")
df5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age23.csv")
df6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age46.csv")

df_llm = (
    df1
    .merge(df1[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df3[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df4[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df5[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df6[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

llm =df_llm[["GPT_5.4_mini_df1","GPT_5.4_mini_df2","GPT_5.4_mini_df3","GPT_5.4_mini_df4","GPT_5.4_mini_df5","GPT_5.4_mini_df6"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT 5.4_mini models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT 5.4_mini models
# 0.8323077457737249

# %% [markdown]
# **GPT 5.4 nano**

# %%
df1 = pd.read_csv("LLM_annotation2/GPT_5.4_nano_EXIST2023.csv")
df2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_nano_EXIST2023.csv")
df3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_nano_EXIST2023.csv")
df4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age18.csv")
df5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age23.csv")
df6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age46.csv")

df_llm = (
    df1
    .merge(df1[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df2[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df4[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df5[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df6[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

llm =df_llm[["GPT_5.4_nano_df1","GPT_5.4_nano_df2","GPT_5.4_nano_df3","GPT_5.4_nano_df4","GPT_5.4_nano_df5","GPT_5.4_nano_df6"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT 5.4_nano models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT 5.4_nano models
# 0.7325980072948741

# %% [markdown]
# **GPT 5.5**

# %%
df1 = pd.read_csv("LLM_annotation2/GPT_5.5_EXIST2023.csv")
df2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.5_EXIST2023.csv")
df3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.5_EXIST2023.csv")
df4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age18.csv")
df5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age23.csv")
df6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age46.csv")

df_llm = (
    df1
    .merge(df1[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df2[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df3[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df5[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df6[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

llm =df_llm[["GPT_5.5_df1","GPT_5.5_df2","GPT_5.5_df3","GPT_5.5_df4","GPT_5.5_df5","GPT_5.5_df6"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT 5.5 models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT 5.5 models
# 0.9383576474727306

# %% [markdown]
# **Phi**

# %%
df1 = pd.read_csv("LLM_annotation2/phi_EXIST2023.csv")
df2=pd.read_csv("LLM_annotation3_female_persona/phi_EXIST2023.csv")
df3=pd.read_csv("LLM_annotation4_male_persona/phi_EXIST2023.csv")
df4=pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age18.csv")
df5=pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age23.csv")
df6=pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age46.csv")

df_llm = (
    df1
    .merge(df1[["id_EXIST", "phi"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df2[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df3[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df4[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df6[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

llm =df_llm[["phi_df1","phi_df2","phi_df3","phi_df4","phi_df5","phi_df6"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the phi models")
print(fleiss)
# Out:
# Fleiss kappa for the phi models
# 0.8945722864792283

# %% [markdown]
# **mistral**

# %%
df1 = pd.read_csv("LLM_annotation2/mistral_EXIST2023_second_time.csv")
df2=pd.read_csv("LLM_annotation3_female_persona/mistral_EXIST2023.csv")
df3=pd.read_csv("LLM_annotation4_male_persona/mistral_EXIST2023.csv")
df4=pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age18.csv")
df5=pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age23.csv")
df6=pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age46.csv")

df_llm = (
    df1
    .merge(df1[["id_EXIST", "mistral"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df2[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df3[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df4[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df5[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

llm =df_llm[["mistral_df1","mistral_df2","mistral_df3","mistral_df4","mistral_df5","mistral_df6"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the mistral models")
print(fleiss)
# Out:
# Fleiss kappa for the mistral models
# 0.9411747438870463

# %% [markdown]
# **Fleiss' kappa across all LLM models for each prompt**

# %% [markdown]
# **PROMPT1 (non persona)**

# %%
df1 = pd.read_csv("LLM_annotation2/GPT_5.4_EXIST2023.csv")
df2 = pd.read_csv("LLM_annotation2/GPT_5.4_mini_EXIST2023.csv")
df3 = pd.read_csv("LLM_annotation2/GPT_5.4_nano_EXIST2023.csv")
df4 = pd.read_csv("LLM_annotation2/GPT_5.5_EXIST2023.csv")
df5 = pd.read_csv("LLM_annotation2/phi_EXIST2023.csv")
df6 = pd.read_csv("LLM_annotation2/mistral_EXIST2023_second_time.csv")


df_llm = (
    df1
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left")
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left")
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left")
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left")
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left")
)

llm =df_llm[["GPT_5.4","GPT_5.4_mini","GPT_5.4_nano","GPT_5.5","phi","mistral"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT prompt1(no-persona) models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT prompt1(no-persona) models
# 0.5038135342837129

# %% [markdown]
# **Prompt 3 female persona**

# %%
df1 = pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_EXIST2023.csv")
df2 = pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_mini_EXIST2023.csv")
df3 = pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_nano_EXIST2023.csv")
df4 = pd.read_csv("LLM_annotation3_female_persona/GPT_5.5_EXIST2023.csv")
df5 = pd.read_csv("LLM_annotation3_female_persona/phi_EXIST2023.csv")
df6 = pd.read_csv("LLM_annotation3_female_persona/mistral_EXIST2023.csv")


df_llm = (
    df1
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left")
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left")
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left")
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left")
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left")
)

llm =df_llm[["GPT_5.4","GPT_5.4_mini","GPT_5.4_nano","GPT_5.5","phi","mistral"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT prompt2 female persona models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT prompt2 female persona models
# 0.46721886963925763

# %% [markdown]
# **Prompt 4 male persona**

# %%
df1 = pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_EXIST2023.csv")
df2 = pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_mini_EXIST2023.csv")
df3 = pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_nano_EXIST2023.csv")
df4 = pd.read_csv("LLM_annotation4_male_persona/GPT_5.5_EXIST2023.csv")
df5 = pd.read_csv("LLM_annotation4_male_persona/phi_EXIST2023.csv")
df6 = pd.read_csv("LLM_annotation4_male_persona/mistral_EXIST2023.csv")


df_llm = (
    df1
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left")
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left")
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left")
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left")
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left")
)

llm =df_llm[["GPT_5.4","GPT_5.4_mini","GPT_5.4_nano","GPT_5.5","phi","mistral"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT prompt3 male models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT prompt3 male models
# 0.4717066850597423

# %% [markdown]
# **Age1 persona**

# %%
df1 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age18.csv")
df2 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age18.csv")
df3 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age18.csv")
df4 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age18.csv")
df5 = pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age18.csv")
df6 = pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age18.csv")


df_llm = (
    df1
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left")
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left")
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left")
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left")
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left")
)

llm =df_llm[["GPT_5.4","GPT_5.4_mini","GPT_5.4_nano","GPT_5.5","phi","mistral"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT age1 persona models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT age1 persona models
# 0.4769462378059535

# %% [markdown]
# **Age2 persona**

# %%
df1 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age23.csv")
df2 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age23.csv")
df3 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age23.csv")
df4 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age23.csv")
df5 = pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age23.csv")
df6 = pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age23.csv")


df_llm = (
    df1
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left")
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left")
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left")
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left")
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left")
)

llm =df_llm[["GPT_5.4","GPT_5.4_mini","GPT_5.4_nano","GPT_5.5","phi","mistral"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the GPT age2 persona models")
print(fleiss)
# Out:
# Fleiss kappa for the GPT age2 persona models
# 0.48111092885359413

# %% [markdown]
# **Age3 persona**

# %%
df1 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age46.csv")
df2 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age46.csv")
df3 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age46.csv")
df4 = pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age46.csv")
df5 = pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age46.csv")
df6 = pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age46.csv")


df_llm = (
    df1
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left")
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left")
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left")
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left")
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left")
)

llm =df_llm[["GPT_5.4","GPT_5.4_mini","GPT_5.4_nano","GPT_5.5","phi","mistral"]]


llm = llm.apply(lambda col: col.map({"YES": 1, "NO": 0})).astype(int)

table, _ = aggregate_raters(llm.to_numpy()) #for fleiss kappa, we need to aggregated annotators; rows as subjects and annotators as columns; fleiss kappa consider (items, annotators)
#print(table)

fleiss = fleiss_kappa(table)
print("Fleiss kappa for the age3 models")
print(fleiss)
# Out:
# Fleiss kappa for the age3 models
# 0.460951198078388

# %% [markdown]
# Extra coding

# %%
df_llm = (
    df1
    .merge(df1[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df5[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df6[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

# %%
df_llm
# Out:
#           id  id_EXIST lang  \
# 0     200001    200001   en
# 1     200002    200002   en
# 2     200003    200003   en
# 3     200004    200004   en
# 4     200005    200005   en
# ...      ...       ...  ...
# 3255  203256    203256   en
# 3256  203257    203257   en
# 3257  203258    203258   en
# 3258  203259    203259   en
# 3259  203260    203260   en
#
#                                                   tweet  number_annotators  \
# 0     FFS! How about laying the blame on the bastard...                  6
# 1     Writing a uni essay in my local pub with a cof...                  6
# 2     @UniversalORL it is 2021 not 1921. I dont appr...                  6
# 3     @GMB this is unacceptable. Use her title as yo...                  6
# 4     ‘Making yourself a harder target’ basically bo...                  6
# ...                                                 ...                ...
# 3255  idk why y’all bitches think having half your a...                  6
# ...
