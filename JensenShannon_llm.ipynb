# %% [markdown]
# **Calculated the Jensen–Shannon divergence between one LLM vs another LLMs, with each LLM evaluated using all six prompts.**

# %%
# !pip install scipy

# %% [markdown]
# Calling all LLM annotations

# %%
import pandas as pd
df_gpt54_1 = pd.read_csv("LLM_annotation2/GPT_5.4_EXIST2023.csv")
df_gpt54_2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_EXIST2023.csv")
df_gpt54_3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_EXIST2023.csv")
df_gpt54_4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age18.csv")
df_gpt54_5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age23.csv")
df_gpt54_6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_EXIST2023_age46.csv")



df_mini_1 = pd.read_csv("LLM_annotation2/GPT_5.4_mini_EXIST2023.csv")
df_mini_2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_mini_EXIST2023.csv")
df_mini_3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_mini_EXIST2023.csv")
df_mini_4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age18.csv")
df_mini_5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age23.csv")
df_mini_6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_mini_EXIST2023_age46.csv")


df_nano_1 = pd.read_csv("LLM_annotation2/GPT_5.4_nano_EXIST2023.csv")
df_nano_2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.4_nano_EXIST2023.csv")
df_nano_3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.4_nano_EXIST2023.csv")
df_nano_4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age18.csv")
df_nano_5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age23.csv")
df_nano_6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age46.csv")


df_gpt55_1 = pd.read_csv("LLM_annotation2/GPT_5.5_EXIST2023.csv")
df_gpt55_2=pd.read_csv("LLM_annotation3_female_persona/GPT_5.5_EXIST2023.csv")
df_gpt55_3=pd.read_csv("LLM_annotation4_male_persona/GPT_5.5_EXIST2023.csv")
df_gpt55_4=pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age18.csv")
df_gpt55_5=pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age23.csv")
df_gpt55_6=pd.read_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age46.csv")


df_phi_1 = pd.read_csv("LLM_annotation2/phi_EXIST2023.csv")
df_phi_2=pd.read_csv("LLM_annotation3_female_persona/phi_EXIST2023.csv")
df_phi_3=pd.read_csv("LLM_annotation4_male_persona/phi_EXIST2023.csv")
df_phi_4=pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age18.csv")
df_phi_5=pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age23.csv")
df_phi_6=pd.read_csv("LLM_annotation5_age_persona/phi_EXIST2023_age46.csv")


df_mistral_1 = pd.read_csv("LLM_annotation2/mistral_EXIST2023_second_time.csv")
df_mistral_2=pd.read_csv("LLM_annotation3_female_persona/mistral_EXIST2023.csv")
df_mistral_3=pd.read_csv("LLM_annotation4_male_persona/mistral_EXIST2023.csv")
df_mistral_4=pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age18.csv")
df_mistral_5=pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age23.csv")
df_mistral_6=pd.read_csv("LLM_annotation5_age_persona/mistral_EXIST2023_age46.csv")

# %% [markdown]
# Joining the annotaitons from different LLM models

# %%
df_llm = (
    df_gpt54_1
    .merge(df_gpt54_1[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df_gpt54_2[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df_gpt54_3[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df_gpt54_4[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df_gpt54_5[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df_gpt54_6[["id_EXIST", "GPT_5.4"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)



df_llm = df_llm.merge(
    df_mini_1
    .merge(df_mini_1[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df_mini_2[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df_mini_3[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df_mini_4[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df_mini_5[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df_mini_6[["id_EXIST", "GPT_5.4_mini"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)


df_llm =df_llm.merge(
    df_nano_1
    .merge(df_nano_1[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df_nano_2[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df_nano_3[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df_nano_4[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df_nano_5[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df_nano_6[["id_EXIST", "GPT_5.4_nano"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)



df_llm =df_llm.merge(
    df_gpt55_1
    .merge(df_gpt55_1[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df_gpt55_2[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df_gpt55_3[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df_gpt55_4[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df_gpt55_5[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df_gpt55_6[["id_EXIST", "GPT_5.5"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)



df_llm = df_llm.merge(
    df_phi_1
    .merge(df_phi_1[["id_EXIST", "phi"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df_phi_2[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df_phi_3[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df_phi_4[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df_phi_5[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df_phi_6[["id_EXIST", "phi"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)


df_llm = df_llm.merge(
    df_mistral_1
    .merge(df_mistral_1[["id_EXIST", "mistral"]], on="id_EXIST", how="left",suffixes=("", "_df1"))
    .merge(df_mistral_2[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df2"))
    .merge(df_mistral_3[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df3"))
    .merge(df_mistral_4[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df4"))
    .merge(df_mistral_5[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df5"))
    .merge(df_mistral_6[["id_EXIST", "mistral"]], on="id_EXIST", how="left", suffixes=("", "_df6"))
)

# %%
df_llm.columns

# %%
gpt54_cols =["GPT_5.4_df1","GPT_5.4_df2","GPT_5.4_df3","GPT_5.4_df4","GPT_5.4_df5","GPT_5.4_df6"]
mini_cols=["GPT_5.4_mini_df1","GPT_5.4_mini_df2","GPT_5.4_mini_df3","GPT_5.4_mini_df4","GPT_5.4_mini_df5","GPT_5.4_mini_df6"]

nano_cols=["GPT_5.4_nano_df1","GPT_5.4_nano_df2","GPT_5.4_nano_df3","GPT_5.4_nano_df4","GPT_5.4_nano_df5","GPT_5.4_nano_df6"]
gpt55_cols=["GPT_5.5_df1","GPT_5.5_df2","GPT_5.5_df3","GPT_5.5_df4","GPT_5.5_df5","GPT_5.5_df6"]

phi_cols=["phi_df1","phi_df2","phi_df3","phi_df4","phi_df5","phi_df6"]

mistral_cols=["mistral_df1","mistral_df2","mistral_df3","mistral_df4","mistral_df5","mistral_df6"]

# %%
from scipy.spatial.distance import jensenshannon #this function gives Jensen-Shannon distance between two probability arrays. this is the square root of the Jensen-Shannon divergence


def jsd(df_llm,llm1_cols,llm2_cols):

    df_llm["llm1_prob"] = (
        df_llm[llm1_cols]
        .apply(lambda row: row.astype(str).str.upper().eq("YES").mean(), axis=1)
    )

    df_llm["llm2_prob"] = (
        df_llm[llm2_cols]
        .apply(lambda row: row.astype(str).str.upper().eq("YES").mean(), axis=1)
    )

    # Round human_prob to 2 decimal places
    df_llm["llm1_prob"] = df_llm["llm1_prob"].round(2)

    # If you also want to round llm_prob
    df_llm["llm2_prob"] = df_llm["llm2_prob"].round(2)
    
    df_llm["jsd"] = df_llm.apply(
        lambda row: jensenshannon(
            [row["llm1_prob"], 1-row["llm1_prob"]],
            [row["llm2_prob"], 1-row["llm2_prob"]],
            base=2
        #),  #this gives Jensen Shannon distance
        )**2,     # square it to obtain Jensen-Shannon divergence 
        axis=1
    )
    return df_llm

# %% [markdown]
# **GPT 5.4 vs GPT nano**

# %%
df_llm_gpt54_gptnano=jsd(df_llm,gpt54_cols,nano_cols)
print(df_llm_gpt54_gptnano["jsd"].describe())

# %% [markdown]
# **GPT 5.4 vs GPT mini**

# %%
df_llm_gpt54_gptmini=jsd(df_llm,gpt54_cols,mini_cols)
print(df_llm_gpt54_gptmini["jsd"].describe())

# %% [markdown]
# **GPT 5.4 vs GPT 5.5**

# %%
df_llm_gpt54_gpt55=jsd(df_llm,gpt54_cols,gpt55_cols)
print(df_llm_gpt54_gpt55["jsd"].describe())

# %% [markdown]
# **GPT 5.4 vs Phi**

# %%
df_llm_gpt54_phi=jsd(df_llm,gpt54_cols,phi_cols)
print(df_llm_gpt54_phi["jsd"].describe())

# %% [markdown]
# **GPT 5.4 vs Mistral**

# %%
df_llm_gpt54_mistral=jsd(df_llm,gpt54_cols,mistral_cols)
print(df_llm_gpt54_mistral["jsd"].describe())

# %% [markdown]
# **GPT mini vs GPT Nano**

# %%
df_llm_gptmini_gptnano=jsd(df_llm,mini_cols,nano_cols)
print(df_llm_gptmini_gptnano["jsd"].describe())

# %% [markdown]
# **GPT mini vs GPT 5.5**

# %%
df_llm_gptmini_gpt55=jsd(df_llm,mini_cols,gpt55_cols)
print(df_llm_gptmini_gpt55["jsd"].describe())

# %% [markdown]
# **GPT mini vs phi**

# %%
df_llm_gptmini_phi=jsd(df_llm,mini_cols,phi_cols)
print(df_llm_gptmini_phi["jsd"].describe())

# %% [markdown]
# **GPT mini vs mistral**

# %%
df_llm_gptmini_mistral=jsd(df_llm,mini_cols,mistral_cols)
print(df_llm_gptmini_mistral["jsd"].describe())

# %% [markdown]
# **GPT nano vs GPT 5.5**

# %%
df_llm_nano_gpt55=jsd(df_llm,nano_cols,gpt55_cols)
print(df_llm_nano_gpt55["jsd"].describe())

# %% [markdown]
# **GPT nano vs Phi**

# %%
df_llm_nano_phi=jsd(df_llm,nano_cols,phi_cols)
print(df_llm_nano_phi["jsd"].describe())

# %% [markdown]
# **GPT nano vs mistral**

# %%
df_llm_nano_mistral=jsd(df_llm,nano_cols,mistral_cols)
print(df_llm_nano_mistral["jsd"].describe())

# %% [markdown]
# **GPT 5.5 vs phi**

# %%
df_llm_gpt55_phi=jsd(df_llm,gpt55_cols,phi_cols)
print(df_llm_gpt55_phi["jsd"].describe())

# %% [markdown]
# **GPT 5.5 vs mistral**

# %%
df_llm_gpt55_mistral=jsd(df_llm,gpt55_cols,mistral_cols)
print(df_llm_gpt55_mistral["jsd"].describe())

# %% [markdown]
# **Phi vs Mistral**

# %%
df_llm_phi_mistral=jsd(df_llm,phi_cols,mistral_cols)
print(df_llm_phi_mistral["jsd"].describe())
