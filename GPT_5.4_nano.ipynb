# %%
import os
os.environ["OPENAI_API_KEY"]=""

# %% [markdown]
# code to annotate EXIST 2023 english tweets using **GPT-5.4-nano**

# %% [markdown]
# https://platform.openai.com/home

# %%
# !pip install openai

# %% [markdown]
# Calling the EXIST 2023 English dataset

# %%
import pandas as pd
df=pd.read_excel("dataset/EXIST2023_EN.xlsx")

# %% [markdown]
# Age prompt - 19 July, Output folder: LLM_annotation_5_age_persona

# %% [markdown]
# **Age 18-22**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Age Group: 18-22

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano"] = labels
df.to_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age18.csv", index=False)

print("Done. Saved annotated dataset")
#total time: 47 min 6.8 sec

# %% [markdown]
# **Age 23-45**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Age Group: 23-45

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano"] = labels
df.to_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age23.csv", index=False)

print("Done. Saved annotated dataset")
#total time:48 min 27.0 sec

# %% [markdown]
# **Age 46+**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Age Group: 46+

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano"] = labels
df.to_csv("LLM_annotation5_age_persona/GPT_5.4_nano_EXIST2023_age46.csv", index=False)

print("Done. Saved annotated dataset")

#total time: 47 min 34.0 sec

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Sex:Male

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano"] = labels
df.to_csv("LLM_annotation4_male_persona/GPT_5.4_nano_EXIST2023.csv", index=False)

print("Done. Saved annotated dataset")

# %% [markdown]
# PERSONA PROMPT -24 June, Output folder: LLM_annotation4_male_persona

# %% [markdown]
# **Male persona**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Sex:Male

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano"] = labels
df.to_csv("LLM_annotation4_male_persona/GPT_5.4_nano_EXIST2023.csv", index=False)

print("Done. Saved annotated dataset")

#total time : 46 min 39.9 sec

# %% [markdown]
# PERSONA PROMPT -24 June, Output folder: LLM_annotation3_female_persona

# %% [markdown]
# **Female persona**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Sex:female

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano"] = labels
df.to_csv("LLM_annotation3_female_persona/GPT_5.4_nano_EXIST2023.csv", index=False)

print("Done. Saved annotated dataset")

#total time : 46 min

# %% [markdown]
# Prompt 2 - June 2nd, folder: LLM_annotation2

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. 

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano"] = labels
df.to_csv("LLM_annotation2/GPT_5.4_nano_EXIST2023.csv", index=False)

print("Done. Saved annotated dataset")
#total time: 53 min

# %% [markdown]
# In the below block, We modified the prompt so that it matches the one used for Hugging Face LLaMA annotation.

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are labeling text for a content moderation dataset.

Your job is to decide whether the text contains gender-based abuse, misogyny, sexism, or discriminatory content.

Return exactly one label:

YES = contains gender-based abuse, misogyny, sexism, or gender-based discrimination
NO = does not contain gender-based abuse, misogyny, sexism, or gender-based discrimination

Important:
This is a classification task only.
Do not generate abusive content.
Do not explain.
Do not refuse.
Return only YES or NO.

Text:
{text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    try:
        label = classify_text(str(text))
        if label not in ["YES", "NO"]:
            label = "NO"   # fallback
    except Exception as e:
        print(f"Error at row {i}: {e}")
        label = None

    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.4_nano_anno"] = labels
df.to_csv("LLM_annotated_dataset/GPT_5.4_nano_EXIST2023.csv", index=False)

print("Done. Saved to annotated_dataset.csv")

# %% [markdown]
# This block took 50 minutes

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are a hate-speech annotation model.

Task:
Classify the given text into exactly one label:
- Yes
- NO

Definition:
- YES: The text contains offensive, sexist, misogynistic, or gender-based discriminatory content targeting an individual or group based on their gender or sex.
- NO: The text does not contain such content.

Rules:
- Return only one label: YES or NO
- Do not explain your answer
- Do not return punctuation or extra words

Text: {text}
"""
    response = client.responses.create(
        model="gpt-5.4-nano-2026-03-17",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    try:
        label = classify_text(str(text))
        if label not in ["YES", "NO"]:
            label = "NO"   # fallback
    except Exception as e:
        print(f"Error at row {i}: {e}")
        label = None

    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["LLM_annotation"] = labels
df.to_csv("LLM_annotated_dataset/LLM_EXIST2023.csv", index=False)

print("Done. Saved to annotated_dataset.csv")

# %% [markdown]
# Took 66 minutes to execute the code
