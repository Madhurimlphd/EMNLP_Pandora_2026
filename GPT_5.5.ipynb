# %%
import os
os.environ["OPENAI_API_KEY"]=""

# %% [markdown]
# https://platform.openai.com/home

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.11/site-packages (2.30.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.10.12)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Calling the EXIST 2023 English dataset

# %%
import pandas as pd
df=pd.read_excel("dataset/EXIST2023_EN.xlsx")

# %%
#df=df.head(20)

# %% [markdown]
# Age prompt - 19 July, Output folder: LLM_annotation_5_age_persona

# %% [markdown]
# **Age 18-22**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Age Group: 18-22

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.5-2026-04-23",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.5"] = labels
df.to_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age18.csv", index=False)

print("Done. Saved annotated dataset")

#total time: 178 min 46.7 sec
# Out:
# Processed 100/3260 rows
# Processed 200/3260 rows
# Processed 300/3260 rows
# Processed 400/3260 rows
# Processed 500/3260 rows
# Processed 600/3260 rows
# Processed 700/3260 rows
# Processed 800/3260 rows
# Processed 900/3260 rows
# Processed 1000/3260 rows
# Processed 1100/3260 rows
# Processed 1200/3260 rows
# Processed 1300/3260 rows
# Processed 1400/3260 rows
# Processed 1500/3260 rows
# Processed 1600/3260 rows
# Processed 1700/3260 rows
# Processed 1800/3260 rows
# Processed 1900/3260 rows
# Processed 2000/3260 rows
# Processed 2100/3260 rows
# Processed 2200/3260 rows
# Processed 2300/3260 rows
# Processed 2400/3260 rows
# Processed 2500/3260 rows
# Processed 2600/3260 rows
# Processed 2700/3260 rows
# Processed 2800/3260 rows
# Processed 2900/3260 rows
# Processed 3000/3260 rows
# Processed 3100/3260 rows
# Processed 3200/3260 rows
# Done. Saved annotated dataset

# %% [markdown]
# **Age 23-45**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Age Group: 23-45

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.5-2026-04-23",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.5"] = labels
df.to_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age23.csv", index=False)

print("Done. Saved annotated dataset")

#total time: 174 min 11.6 sec
# Out:
# Processed 100/3260 rows
# Processed 200/3260 rows
# Processed 300/3260 rows
# Processed 400/3260 rows
# Processed 500/3260 rows
# Processed 600/3260 rows
# Processed 700/3260 rows
# Processed 800/3260 rows
# Processed 900/3260 rows
# Processed 1000/3260 rows
# Processed 1100/3260 rows
# Processed 1200/3260 rows
# Processed 1300/3260 rows
# Processed 1400/3260 rows
# Processed 1500/3260 rows
# Processed 1600/3260 rows
# Processed 1700/3260 rows
# Processed 1800/3260 rows
# Processed 1900/3260 rows
# Processed 2000/3260 rows
# Processed 2100/3260 rows
# Processed 2200/3260 rows
# Processed 2300/3260 rows
# Processed 2400/3260 rows
# Processed 2500/3260 rows
# Processed 2600/3260 rows
# Processed 2700/3260 rows
# Processed 2800/3260 rows
# Processed 2900/3260 rows
# Processed 3000/3260 rows
# Processed 3100/3260 rows
# Processed 3200/3260 rows
# Done. Saved annotated dataset

# %% [markdown]
# **Age 46+**

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Age Group: 46+

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.5-2026-04-23",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.5"] = labels
df.to_csv("LLM_annotation5_age_persona/GPT_5.5_EXIST2023_age46.csv", index=False)

print("Done. Saved annotated dataset")

#total time: 170 min 44.6 sec
# Out:
# Processed 100/3260 rows
# Processed 200/3260 rows
# Processed 300/3260 rows
# Processed 400/3260 rows
# Processed 500/3260 rows
# Processed 600/3260 rows
# Processed 700/3260 rows
# Processed 800/3260 rows
# Processed 900/3260 rows
# Processed 1000/3260 rows
# Processed 1100/3260 rows
# Processed 1200/3260 rows
# Processed 1300/3260 rows
# Processed 1400/3260 rows
# Processed 1500/3260 rows
# Processed 1600/3260 rows
# Processed 1700/3260 rows
# Processed 1800/3260 rows
# Processed 1900/3260 rows
# Processed 2000/3260 rows
# Processed 2100/3260 rows
# Processed 2200/3260 rows
# Processed 2300/3260 rows
# Processed 2400/3260 rows
# Processed 2500/3260 rows
# Processed 2600/3260 rows
# Processed 2700/3260 rows
# Processed 2800/3260 rows
# Processed 2900/3260 rows
# Processed 3000/3260 rows
# Processed 3100/3260 rows
# Processed 3200/3260 rows
# Done. Saved annotated dataset

# %% [markdown]
# PERSONA PROMPT 4 -24 June, Output folder: LLM_annotation4_male_persona

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Sex:Male

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.5-2026-04-23",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.5"] = labels
df.to_csv("LLM_annotation4_male_persona/GPT_5.5_EXIST2023.csv", index=False)

print("Done. Saved annotated dataset")

#total time: 175 m 15.7sec
# Out:
# Processed 100/3260 rows
# Processed 200/3260 rows
# Processed 300/3260 rows
# Processed 400/3260 rows
# Processed 500/3260 rows
# Processed 600/3260 rows
# Processed 700/3260 rows
# Processed 800/3260 rows
# Processed 900/3260 rows
# Processed 1000/3260 rows
# Processed 1100/3260 rows
# Processed 1200/3260 rows
# Processed 1300/3260 rows
# Processed 1400/3260 rows
# Processed 1500/3260 rows
# Processed 1600/3260 rows
# Processed 1700/3260 rows
# Processed 1800/3260 rows
# Processed 1900/3260 rows
# Processed 2000/3260 rows
# Processed 2100/3260 rows
# Processed 2200/3260 rows
# Processed 2300/3260 rows
# Processed 2400/3260 rows
# Processed 2500/3260 rows
# Processed 2600/3260 rows
# Processed 2700/3260 rows
# Processed 2800/3260 rows
# Processed 2900/3260 rows
# Processed 3000/3260 rows
# Processed 3100/3260 rows
# Processed 3200/3260 rows
# Done. Saved annotated dataset

# %% [markdown]
# #PERSONA PROMPT 3 -24 June, Output folder: LLM_annotation3_female_persona

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. Your demographic information is as follows:
-Sex:female

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.5-2026-04-23",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.5"] = labels
df.to_csv("LLM_annotation3_female_persona/GPT_5.5_EXIST2023.csv", index=False)

print("Done. Saved annotated dataset")

#total time: 165 min 39 sec
# Out:
# Processed 100/3260 rows
# Processed 200/3260 rows
# Processed 300/3260 rows
# Processed 400/3260 rows
# Processed 500/3260 rows
# Processed 600/3260 rows
# Processed 700/3260 rows
# Processed 800/3260 rows
# Processed 900/3260 rows
# Processed 1000/3260 rows
# Processed 1100/3260 rows
# Processed 1200/3260 rows
# Processed 1300/3260 rows
# Processed 1400/3260 rows
# Processed 1500/3260 rows
# Processed 1600/3260 rows
# Processed 1700/3260 rows
# Processed 1800/3260 rows
# Processed 1900/3260 rows
# Processed 2000/3260 rows
# Processed 2100/3260 rows
# Processed 2200/3260 rows
# Processed 2300/3260 rows
# Processed 2400/3260 rows
# Processed 2500/3260 rows
# Processed 2600/3260 rows
# Processed 2700/3260 rows
# Processed 2800/3260 rows
# Processed 2900/3260 rows
# Processed 3000/3260 rows
# Processed 3100/3260 rows
# Processed 3200/3260 rows
# Done. Saved annotated dataset

# %% [markdown]
# Prompt 2 - June 2nd, folder: LLM_annotation2

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are an expert linguist specialising in detecting sexism in social media texts. 

Task: Analyse the given tweet and determine whether it contains sexist expressions or behaviors. This includes tweets that:
- Are sexist themselves (contain sexist language or promote sexist ideas).
- Describe a sexist situation (narrate or depict scenarios where sexism occurs).
- Criticise sexist behavior (call out or oppose sexism).

Instructions:
1. Read the Tweet Carefully: Examine the content of the tweet thoroughly.
2. Make Determination: Decide if the tweet fits any of the above categories related to sexism.
3. Classification:
- Assign "YES" if the tweet contains any form of sexist content as defined.
- Assign "NO" if the tweet does not contain sexist context. 
4. Output Format: Provide the assigned category in plain text.
5. Constraint: You must not retrieve any text apart from the two possible categories, YES and NO.

TWEET:
{text}
"""
    response = client.responses.create(
        model="gpt-5.5-2026-04-23",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    label = classify_text(str(text))
    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.5"] = labels
df.to_csv("LLM_annotation2/GPT_5.5_EXIST2023.csv", index=False)

print("Done. Saved annotated dataset")

#total time for execution: 195 minutes, 57 seconds
# Out:
# Processed 100/3260 rows
# Processed 200/3260 rows
# Processed 300/3260 rows
# Processed 400/3260 rows
# Processed 500/3260 rows
# Processed 600/3260 rows
# Processed 700/3260 rows
# Processed 800/3260 rows
# Processed 900/3260 rows
# Processed 1000/3260 rows
# Processed 1100/3260 rows
# Processed 1200/3260 rows
# Processed 1300/3260 rows
# Processed 1400/3260 rows
# Processed 1500/3260 rows
# Processed 1600/3260 rows
# Processed 1700/3260 rows
# Processed 1800/3260 rows
# Processed 1900/3260 rows
# Processed 2000/3260 rows
# Processed 2100/3260 rows
# Processed 2200/3260 rows
# Processed 2300/3260 rows
# Processed 2400/3260 rows
# Processed 2500/3260 rows
# Processed 2600/3260 rows
# Processed 2700/3260 rows
# Processed 2800/3260 rows
# Processed 2900/3260 rows
# Processed 3000/3260 rows
# Processed 3100/3260 rows
# Processed 3200/3260 rows
# Done. Saved annotated dataset

# %% [markdown]
# https://developers.openai.com/api/docs/models/gpt-5.5

# %%
from openai import OpenAI
import time

client = OpenAI()
def classify_text(text: str) -> str:
    prompt = f"""
You are labeling text for a content moderation dataset.

Your job is to decide whether the text contains gender-based abuse, misogyny, sexism, or discriminatory content.

Return exactly one label:

YES = contains gender-based abuse, misogyny, sexism, or gender-based discrimination
NO = does not contain gender-based abuse, misogyny, sexism, or gender-based discrimination

Important:
This is a classification task only.
Do not generate abusive content.
Do not explain.
Do not refuse.
Return only YES or NO.

Text:
{text}
"""
    response = client.responses.create(
        model="gpt-5.5-2026-04-23",
        input=prompt,
    )
    #return response.output_text.strip().lower()
    return response.output_text.strip()

# Annotate all rows
labels = []

for i, text in enumerate(df["tweet"]):
    try:
        label = classify_text(str(text))
        if label not in ["YES", "NO"]:
            label = "NO"   # fallback
    except Exception as e:
        print(f"Error at row {i}: {e}")
        # Stop if quota exhausted
        if "insufficient_quota" in str(e):
            print("API quota exhausted. Stopping process.")
            break

        label = None

    labels.append(label)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(df)} rows")
        time.sleep(1)  # small pause to reduce rate-limit risk

# Save results
df["GPT_5.5_anno"] = labels
df.to_csv("LLM_annotated_dataset/GPT_5.5_EXIST2023.csv", index=False)

print("Done. Saved GPT 5.5 annotated dataset")

#total time: 138 min, 10 sec
# Out:
# Processed 100/3260 rows
# Processed 200/3260 rows
# Processed 300/3260 rows
# Processed 400/3260 rows
# Processed 500/3260 rows
# Processed 600/3260 rows
# Processed 700/3260 rows
# Processed 800/3260 rows
# Processed 900/3260 rows
# Processed 1000/3260 rows
# Processed 1100/3260 rows
# Processed 1200/3260 rows
# Processed 1300/3260 rows
# Processed 1400/3260 rows
# Processed 1500/3260 rows
# Processed 1600/3260 rows
# Processed 1700/3260 rows
# Processed 1800/3260 rows
# Processed 1900/3260 rows
# Processed 2000/3260 rows
# Processed 2100/3260 rows
# Processed 2200/3260 rows
# Processed 2300/3260 rows
# Processed 2400/3260 rows
# Processed 2500/3260 rows
# Processed 2600/3260 rows
# Processed 2700/3260 rows
# Processed 2800/3260 rows
# Processed 2900/3260 rows
# Processed 3000/3260 rows
# Processed 3100/3260 rows
# Processed 3200/3260 rows
# Done. Saved GPT 5.5 annotated dataset
